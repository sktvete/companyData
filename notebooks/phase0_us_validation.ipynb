# %% [markdown]
# # Phase 0 US Validation
#
# Use this notebook to validate ingestion coverage, factor distributions, and the first GARP ranking outputs. Business logic must stay in `src/`.

# %%
from pathlib import Path
import json
root = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
output_dir = root / 'outputs' / 'us_sample'
sorted(output_dir.glob('**/rankings.csv'))[-1] if output_dir.exists() else 'No ranking outputs yet'
